# %% [markdown]
# # US Income

# %%
import keras
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score,recall_score

from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout, BatchNormalization
# Out:
# Using TensorFlow backend.

# %%
random_seed = 342
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# %% [markdown]
# ## Data
# Import data and print some characteristics.

# %%
df = pd.read_csv(r'~/tf-keras/8_US_income/adult.csv')
df = df.drop('fnlwgt', axis=1)

# %%
print('Number of columns:    ', df.shape[1])
print('Number of row:        ', df.shape[0])
print ("\nMissing values :  ", df.isnull().sum().values.sum())
print ("\nUnique values :  \n",df.nunique())
# Out:
# Number of columns:     14
# Number of row:         48842
#
# Missing values :   0
#
# Unique values :
#  age                 74
# workclass            9
# education           16
# educational-num     16
# marital-status       7
# occupation          15
# relationship         6
# race                 5
# gender               2
# capital-gain       123
# capital-loss        99
# hours-per-week      96
# native-country      42
# income               2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   education        48842 non-null  object
#  3   educational-num  48842 non-null  int64
#  4   marital-status   48842 non-null  object
#  5   occupation       48842 non-null  object
#  6   relationship     48842 non-null  object
#  7   race             48842 non-null  object
#  8   gender           48842 non-null  object
#  9   capital-gain     48842 non-null  int64
#  10  capital-loss     48842 non-null  int64
#  11  hours-per-week   48842 non-null  int64
#  12  native-country   48842 non-null  object
#  13  income           48842 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 5.2+ MB

# %%
sns.pairplot(df)
plt.show()

# %%
df.income.describe()
# Out:
# count     48842
# unique        2
# top       <=50K
# freq      37155
# Name: income, dtype: object

# %%
sns.boxplot('age', 'income', data = df)
plt.show()

# %%
sns.boxplot('educational-num', 'income', data = df)
plt.show()

# %% [markdown]
# ## Prepare data for machine learning

# %%
df.drop('educational-num', axis=1, inplace=True, errors='ignore')

target_col = 'income'
bin_vars = []
cat_vars = []
num_vars = []
for i in df.columns:
    if df.nunique()[i] == 2:
        bin_vars.append(i)
    elif df.nunique()[i] < 50:
        cat_vars.append(i)
    else:
        num_vars.append(i)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in bin_vars:
      df[i] = le.fit_transform(df[i])
      print(f'column {i} converted to binary (numerical)')
# Out:
# column gender converted to binary (numerical)
# column income converted to binary (numerical)

# %%
df = pd.get_dummies(data = df, columns = cat_vars)

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
scaled_df = std.fit_transform(df[num_vars])
scaled_df = pd.DataFrame(scaled_df,columns=num_vars)

# %%
df_orig = df.copy()
df = df.drop(columns = num_vars, axis = 1, errors='ignore')
df = df.merge(scaled_df, left_index=True,right_index=True,how = "left")
df = df.dropna()
df.describe()
# Out:
#              gender        income   workclass_?  workclass_Federal-gov  \
# count  48842.000000  48842.000000  48842.000000           48842.000000
# mean       0.668482      0.239282      0.057307               0.029319
# std        0.470764      0.426649      0.232431               0.168701
# min        0.000000      0.000000      0.000000               0.000000
# 25%        0.000000      0.000000      0.000000               0.000000
# 50%        1.000000      0.000000      0.000000               0.000000
# 75%        1.000000      0.000000      0.000000               0.000000
# max        1.000000      1.000000      1.000000               1.000000
#
#        workclass_Local-gov  workclass_Never-worked  workclass_Private  \
# count         48842.000000            48842.000000       48842.000000
# mean              0.064207                0.000205           0.694198
# std               0.245124                0.014307           0.460751
# min               0.000000                0.000000           0.000000
# 25%               0.000000                0.000000           0.000000
# 50%               0.000000                0.000000           1.000000
# 75%               0.000000                0.000000           1.000000
# max               1.000000                1.000000           1.000000
#
#        workclass_Self-emp-inc  workclass_Self-emp-not-inc  \
# count            48842.000000                48842.000000
# mean                 0.034704                    0.079071
# std                  0.183030                    0.269853
# min                  0.000000                    0.000000
# 25%                  0.000000                    0.000000
# 50%                  0.000000                    0.000000
# 75%                  0.000000                    0.000000
# max                  1.000000                    1.000000
#
#        workclass_State-gov  ...  native-country_Taiwan  \
# count         48842.000000  ...           48842.000000
# mean              0.040559  ...               0.001331
# std               0.197269  ...               0.036457
# min               0.000000  ...               0.000000
# 25%               0.000000  ...               0.000000
# 50%               0.000000  ...               0.000000
# 75%               0.000000  ...               0.000000
# max               1.000000  ...               1.000000
#
#        native-country_Thailand  native-country_Trinadad&Tobago  \
# count             48842.000000                    48842.000000
# mean                  0.000614                        0.000553
# std                   0.024776                        0.023506
# min                   0.000000                        0.000000
# 25%                   0.000000                        0.000000
# 50%                   0.000000                        0.000000
# 75%                   0.000000                        0.000000
# max                   1.000000                        1.000000
#
#        native-country_United-States  native-country_Vietnam  \
# count                  48842.000000            48842.000000
# mean                       0.897424                0.001761
# std                        0.303407                0.041925
# min                        0.000000                0.000000
# 25%                        1.000000                0.000000
# 50%                        1.000000                0.000000
# 75%                        1.000000                0.000000
# max                        1.000000                1.000000
#
#        native-country_Yugoslavia           age  capital-gain  capital-loss  \
# count               48842.000000  4.884200e+04  4.884200e+04  4.884200e+04
# mean                    0.000471  1.584958e-16  2.294458e-16  7.617582e-17
# std                     0.021695  1.000010e+00  1.000010e+00  1.000010e+00
# min                     0.000000 -1.578629e+00 -1.448035e-01 -2.171271e-01
# 25%                     0.000000 -7.763164e-01 -1.448035e-01 -2.171271e-01
# 50%                     0.000000 -1.198790e-01 -1.448035e-01 -2.171271e-01
# 75%                     0.000000  6.824334e-01 -1.448035e-01 -2.171271e-01
# max                     1.000000  3.745808e+00  1.327438e+01  1.059179e+01
#
#        hours-per-week
# count    4.884200e+04
# mean     9.071110e-17
# std      1.000010e+00
# min     -3.181452e+00
# 25%     -3.408696e-02
# 50%     -3.408696e-02
# 75%      3.694214e-01
# max      4.727312e+00
#
# [8 rows x 106 columns]

# %%
sns.heatmap(df.corr(), cbar=True, square=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
train,test = train_test_split(df, test_size = .25 ,random_state = random_seed, stratify = df[target_col])
    
# seperating dependent and independent variables
cols    = [i for i in df.columns if i not in target_col]
train_X = train[cols]
train_Y = train[target_col]
test_X  = test[cols]
test_Y  = test[target_col]

# %% [markdown]
# ## Logistic Regression

# %%
logit  = LogisticRegression(C=1.0, class_weight='balanced', dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
          penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
          verbose=0, warm_start=False)

logit.fit(train_X,train_Y)
predictions   = logit.predict(test_X)
probabilities = logit.predict_proba(test_X)
coefficients  = pd.DataFrame(logit.coef_.ravel())

# %%
print ("\n Classification report : \n",classification_report(test_Y,predictions))
print ("Accuracy   Score : ",accuracy_score(test_Y,predictions))
#roc_auc_score
model_roc_auc = roc_auc_score(test_Y,predictions) 
print ("AUC-ROC score : ",model_roc_auc,"\n")
# Out:
#  Classification report :
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86      9289
#            1       0.57      0.84      0.68      2922
#
#     accuracy                           0.81     12211
#    macro avg       0.75      0.82      0.77     12211
# weighted avg       0.85      0.81      0.82     12211
#
# Accuracy   Score :  0.807796249283433
# AUC-ROC score :  0.8198323269027441

# %%
fpr,tpr,thresholds = roc_curve(test_Y,probabilities[:,1])

plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False positives rate')
plt.ylabel('True Positives rate')
plt.title('Logistic ROC curve')
plt.show()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc   = RandomForestClassifier(n_estimators = 100,
                                   criterion = "entropy",
                                   class_weight = 'balanced',
                                  )
rfc.fit(train_X,train_Y)

preds   = rfc.predict(test_X)
probs = rfc.predict_proba(test_X)
coeffs  = pd.DataFrame(rfc.feature_importances_)

# %%
print ("\n Classification report : \n",classification_report(test_Y,preds))
print ("Accuracy   Score : ",accuracy_score(test_Y,preds))
#confusion matrix
conf_matrix = confusion_matrix(test_Y,preds)
print(conf_matrix)
#roc_auc_score
model_roc_auc = roc_auc_score(test_Y,preds) 
print ("AUC-ROC score : ",model_roc_auc,"\n")
# Out:
#  Classification report :
#                precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90      9289
#            1       0.68      0.65      0.67      2922
#
#     accuracy                           0.84     12211
#    macro avg       0.79      0.78      0.78     12211
# weighted avg       0.84      0.84      0.84     12211
#
# Accuracy   Score :  0.8436655474572107
# [[8406  883]
#  [1026 1896]]
# AUC-ROC score :  0.7769059825016584

# %%
fpr,tpr,thresholds = roc_curve(test_Y,probs[:,1])

plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False positives rate')
plt.ylabel('True Positives rate')
plt.title('RF ROC curve')
plt.show()

# %% [markdown]
# ## FC Network

# %%
train_X = train_X.to_numpy()
train_Y = train_Y.to_numpy()
test_X = test_X.to_numpy()
test_Y = test_Y.to_numpy()
train_X.shape
# Out:
# (36631, 105)

# %%
earlystop_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights= True)

# %%
model1 = Sequential([
        Dense(100, activation='tanh', input_shape = train_X.shape[1:]),
        Dropout(0.2),
        Dense(100, activation='tanh', input_shape = train_X.shape[1:]),
        Dropout(0.2),
        Dense(1, activation = 'sigmoid')
        ])
model1.compile(loss = 'binary_crossentropy', optimizer = 'nadam', metrics=['accuracy'])
history1 = model1.fit(train_X, train_Y, epochs=50, validation_data=(test_X, test_Y), callbacks=[earlystop_cb])
# Out:
# Train on 36631 samples, validate on 12211 samples
# Epoch 1/50
# 36631/36631 [==============================] - 2s 68us/step - loss: 0.3356 - accuracy: 0.8445 - val_loss: 0.3193 - val_accuracy: 0.8517
# Epoch 2/50
# 36631/36631 [==============================] - 2s 53us/step - loss: 0.3215 - accuracy: 0.8483 - val_loss: 0.3188 - val_accuracy: 0.8520
# Epoch 3/50
# 36631/36631 [==============================] - 2s 51us/step - loss: 0.3167 - accuracy: 0.8522 - val_loss: 0.3137 - val_accuracy: 0.8576
# Epoch 4/50
# 36631/36631 [==============================] - 2s 52us/step - loss: 0.3140 - accuracy: 0.8527 - val_loss: 0.3113 - val_accuracy: 0.8523
# Epoch 5/50
# 36631/36631 [==============================] - 2s 52us/step - loss: 0.3132 - accuracy: 0.8526 - val_loss: 0.3141 - val_accuracy: 0.8546
# Epoch 6/50
# 36631/36631 [==============================] - 2s 58us/step - loss: 0.3087 - accuracy: 0.8555 - val_loss: 0.3108 - val_accuracy: 0.8579
# Epoch 7/50
# Epoch 27/50
# 36631/36631 [==============================] - 2s 67us/step - loss: 0.2916 - accuracy: 0.8622 - val_loss: 0.3058 - val_accuracy: 0.8601
# Epoch 28/50
# 36631/36631 [==============================] - 2s 60us/step - loss: 0.2892 - accuracy: 0.8642 - val_loss: 0.3044 - val_accuracy: 0.8614
# Epoch 29/50
# 36631/36631 [==============================] - 2s 58us/step - loss: 0.2890 - accuracy: 0.8659 - val_loss: 0.3054 - val_accuracy: 0.8581
# Epoch 30/50
# 36631/36631 [==============================] - 2s 60us/step - loss: 0.2882 - accuracy: 0.8639 - val_loss: 0.3061 - val_accuracy: 0.8613
# Epoch 31/50
# 36631/36631 [==============================] - 2s 63us/step - loss: 0.2881 - accuracy: 0.8648 - val_loss: 0.3117 - val_accuracy: 0.8530
# Epoch 32/50
# 36631/36631 [==============================] - 2s 64us/step - loss: 0.2883 - accuracy: 0.8646 - val_loss: 0.3072 - val_accuracy: 0.8602

# %%
model2 = Sequential([
        Dense(100, activation='relu', input_shape = train_X.shape[1:]),
        Dropout(0.2),
        Dense(100, activation='relu', input_shape = train_X.shape[1:]),
        Dropout(0.2),
        Dense(1, activation = 'sigmoid')
        ])
model2.compile(loss = 'binary_crossentropy', optimizer = 'nadam', metrics=['accuracy'])
history2 = model2.fit(train_X, train_Y, epochs=50, validation_data=(test_X, test_Y), callbacks=[earlystop_cb])
# Out:
# Train on 36631 samples, validate on 12211 samples
# Epoch 1/50
# 36631/36631 [==============================] - 2s 66us/step - loss: 0.3271 - accuracy: 0.8468 - val_loss: 0.3129 - val_accuracy: 0.8578
# Epoch 2/50
# 36631/36631 [==============================] - 2s 59us/step - loss: 0.3117 - accuracy: 0.8566 - val_loss: 0.3107 - val_accuracy: 0.8559
# Epoch 3/50
# 36631/36631 [==============================] - 2s 60us/step - loss: 0.3080 - accuracy: 0.8586 - val_loss: 0.3101 - val_accuracy: 0.8569
# Epoch 4/50
# 36631/36631 [==============================] - 2s 59us/step - loss: 0.3052 - accuracy: 0.8593 - val_loss: 0.3122 - val_accuracy: 0.8570
# Epoch 5/50
# 36631/36631 [==============================] - 2s 60us/step - loss: 0.3019 - accuracy: 0.8596 - val_loss: 0.3086 - val_accuracy: 0.8577
# Epoch 6/50
# 36631/36631 [==============================] - 2s 57us/step - loss: 0.2999 - accuracy: 0.8618 - val_loss: 0.3082 - val_accuracy: 0.8608
# Epoch 7/50
# 36631/36631 [==============================] - 2s 56us/step - loss: 0.2977 - accuracy: 0.8614 - val_loss: 0.3097 - val_accuracy: 0.8582
# Epoch 8/50
# 36631/36631 [==============================] - 2s 56us/step - loss: 0.2939 - accuracy: 0.8650 - val_loss: 0.3109 - val_accuracy: 0.8564
# Epoch 9/50
# 36631/36631 [==============================] - 2s 58us/step - loss: 0.2939 - accuracy: 0.8640 - val_loss: 0.3101 - val_accuracy: 0.8569
# Epoch 10/50
# 36631/36631 [==============================] - 2s 58us/step - loss: 0.2909 - accuracy: 0.8651 - val_loss: 0.3141 - val_accuracy: 0.8593
# Epoch 11/50
# 36631/36631 [==============================] - 2s 56us/step - loss: 0.2895 - accuracy: 0.8653 - val_loss: 0.3179 - val_accuracy: 0.8542
# Epoch 12/50
# 36631/36631 [==============================] - 2s 57us/step - loss: 0.2870 - accuracy: 0.8666 - val_loss: 0.3109 - val_accuracy: 0.8570
# Epoch 13/50
# 36631/36631 [==============================] - 2s 56us/step - loss: 0.2854 - accuracy: 0.8680 - val_loss: 0.3178 - val_accuracy: 0.8589
# Epoch 14/50
# 36631/36631 [==============================] - 2s 59us/step - loss: 0.2833 - accuracy: 0.8679 - val_loss: 0.3175 - val_accuracy: 0.8573
# Epoch 15/50
# 36631/36631 [==============================] - 2s 57us/step - loss: 0.2820 - accuracy: 0.8690 - val_loss: 0.3188 - val_accuracy: 0.8577
# Epoch 16/50
# 36631/36631 [==============================] - 2s 57us/step - loss: 0.2798 - accuracy: 0.8694 - val_loss: 0.3214 - val_accuracy: 0.8561

# %%
model3 = Sequential([
        Dense(100, activation='elu', kernel_initializer = 'he_normal', input_shape = train_X.shape[1:]),
        Dropout(0.2),
        Dense(100, activation='elu', kernel_initializer = 'he_normal', input_shape = train_X.shape[1:]),
        Dropout(0.2),
        Dense(1, activation = 'sigmoid')
        ])
model3.compile(loss = 'binary_crossentropy', optimizer = 'nadam', metrics=['accuracy'])
history3 = model3.fit(train_X, train_Y, epochs=50, validation_data=(test_X, test_Y), callbacks=[earlystop_cb])
# Out:
# Train on 36631 samples, validate on 12211 samples
# Epoch 1/50
# 36631/36631 [==============================] - 2s 63us/step - loss: 0.3349 - accuracy: 0.8423 - val_loss: 0.3197 - val_accuracy: 0.8564
# Epoch 2/50
# 36631/36631 [==============================] - 2s 57us/step - loss: 0.3174 - accuracy: 0.8512 - val_loss: 0.3134 - val_accuracy: 0.8531
# Epoch 3/50
# 36631/36631 [==============================] - 2s 64us/step - loss: 0.3145 - accuracy: 0.8529 - val_loss: 0.3219 - val_accuracy: 0.8489
# Epoch 4/50
# 36631/36631 [==============================] - 2s 65us/step - loss: 0.3133 - accuracy: 0.8551 - val_loss: 0.3113 - val_accuracy: 0.8546
# Epoch 5/50
# 36631/36631 [==============================] - 2s 57us/step - loss: 0.3113 - accuracy: 0.8538 - val_loss: 0.3107 - val_accuracy: 0.8547
# Epoch 6/50
# 36631/36631 [==============================] - 2s 59us/step - loss: 0.3101 - accuracy: 0.8555 - val_loss: 0.3110 - val_accuracy: 0.8551
# Epoch 7/50
# 36631/36631 [==============================] - 2s 59us/step - loss: 0.3095 - accuracy: 0.8555 - val_loss: 0.3077 - val_accuracy: 0.8553
# Epoch 8/50
# 36631/36631 [==============================] - 2s 59us/step - loss: 0.3072 - accuracy: 0.8573 - val_loss: 0.3139 - val_accuracy: 0.8557
# Epoch 9/50
# 36631/36631 [==============================] - 2s 62us/step - loss: 0.3067 - accuracy: 0.8582 - val_loss: 0.3100 - val_accuracy: 0.8552
# Epoch 10/50
# 36631/36631 [==============================] - 2s 58us/step - loss: 0.3058 - accuracy: 0.8557 - val_loss: 0.3064 - val_accuracy: 0.8609
# Epoch 11/50
# 36631/36631 [==============================] - 2s 59us/step - loss: 0.3052 - accuracy: 0.8581 - val_loss: 0.3077 - val_accuracy: 0.8594
# Epoch 12/50
# 36631/36631 [==============================] - 2s 60us/step - loss: 0.3044 - accuracy: 0.8577 - val_loss: 0.3063 - val_accuracy: 0.8564
# Epoch 13/50
# 36631/36631 [==============================] - 2s 62us/step - loss: 0.3038 - accuracy: 0.8592 - val_loss: 0.3087 - val_accuracy: 0.8568
# Epoch 14/50
# 36631/36631 [==============================] - 2s 60us/step - loss: 0.3029 - accuracy: 0.8590 - val_loss: 0.3169 - val_accuracy: 0.8487
# Epoch 15/50
# 36631/36631 [==============================] - 2s 62us/step - loss: 0.3019 - accuracy: 0.8591 - val_loss: 0.3081 - val_accuracy: 0.8595
# Epoch 16/50
# 36631/36631 [==============================] - 2s 59us/step - loss: 0.3018 - accuracy: 0.8597 - val_loss: 0.3105 - val_accuracy: 0.8507
# Epoch 17/50
# 36631/36631 [==============================] - 2s 62us/step - loss: 0.3008 - accuracy: 0.8599 - val_loss: 0.3126 - val_accuracy: 0.8573
# Epoch 18/50
# 36631/36631 [==============================] - 2s 59us/step - loss: 0.2999 - accuracy: 0.8584 - val_loss: 0.3056 - val_accuracy: 0.8607
# Epoch 19/50
# 36631/36631 [==============================] - 2s 60us/step - loss: 0.2984 - accuracy: 0.8603 - val_loss: 0.3172 - val_accuracy: 0.8474
# Epoch 20/50
# 36631/36631 [==============================] - 2s 59us/step - loss: 0.2991 - accuracy: 0.8591 - val_loss: 0.3060 - val_accuracy: 0.8586
# Epoch 21/50
# 36631/36631 [==============================] - 2s 60us/step - loss: 0.2973 - accuracy: 0.8603 - val_loss: 0.3061 - val_accuracy: 0.8605
# Epoch 22/50
# 36631/36631 [==============================] - 2s 62us/step - loss: 0.2974 - accuracy: 0.8600 - val_loss: 0.3078 - val_accuracy: 0.8539
# Epoch 23/50
# 36631/36631 [==============================] - 2s 62us/step - loss: 0.2977 - accuracy: 0.8603 - val_loss: 0.3060 - val_accuracy: 0.8570
# Epoch 24/50
# 36631/36631 [==============================] - 2s 59us/step - loss: 0.2963 - accuracy: 0.8618 - val_loss: 0.3059 - val_accuracy: 0.8613
# Epoch 25/50
# 36631/36631 [==============================] - 2s 61us/step - loss: 0.2967 - accuracy: 0.8613 - val_loss: 0.3070 - val_accuracy: 0.8636
# Epoch 26/50
# 36631/36631 [==============================] - 2s 60us/step - loss: 0.2963 - accuracy: 0.8623 - val_loss: 0.3112 - val_accuracy: 0.8579
# Epoch 27/50
# 36631/36631 [==============================] - 2s 61us/step - loss: 0.2949 - accuracy: 0.8631 - val_loss: 0.3064 - val_accuracy: 0.8612
# Epoch 28/50
# 36631/36631 [==============================] - 2s 64us/step - loss: 0.2942 - accuracy: 0.8624 - val_loss: 0.3111 - val_accuracy: 0.8603

# %%
model4 = Sequential([
        Dense(100, activation='elu', kernel_initializer = 'he_normal', input_shape = train_X.shape[1:]),
        Dropout(0.2),
        BatchNormalization(),
        Dense(100, activation='elu', kernel_initializer = 'he_normal', input_shape = train_X.shape[1:]),
        Dropout(0.2),
        BatchNormalization(),
        Dense(1, activation = 'sigmoid')
        ])
model4.compile(loss = 'binary_crossentropy', optimizer = 'nadam', metrics=['accuracy'])
history4 = model4.fit(train_X, train_Y, epochs=50, validation_data=(test_X, test_Y), callbacks=[earlystop_cb])
# Out:
# Train on 36631 samples, validate on 12211 samples
# Epoch 1/50
# 36631/36631 [==============================] - 3s 88us/step - loss: 0.3591 - accuracy: 0.8334 - val_loss: 0.3179 - val_accuracy: 0.8544
# 36631/36631 [==============================] - 3s 77us/step - loss: 0.3068 - accuracy: 0.8577 - val_loss: 0.3068 - val_accuracy: 0.8610
# Epoch 22/50
# 36631/36631 [==============================] - 3s 84us/step - loss: 0.3067 - accuracy: 0.8574 - val_loss: 0.3082 - val_accuracy: 0.8566
# Epoch 23/50
# 36631/36631 [==============================] - 3s 82us/step - loss: 0.3049 - accuracy: 0.8578 - val_loss: 0.3061 - val_accuracy: 0.8595
# Epoch 24/50
# 36631/36631 [==============================] - 3s 80us/step - loss: 0.3040 - accuracy: 0.8577 - val_loss: 0.3075 - val_accuracy: 0.8581
# Epoch 25/50
# 36631/36631 [==============================] - 3s 79us/step - loss: 0.3042 - accuracy: 0.8587 - val_loss: 0.3058 - val_accuracy: 0.8588
# Epoch 26/50
# 36631/36631 [==============================] - 3s 82us/step - loss: 0.3041 - accuracy: 0.8588 - val_loss: 0.3082 - val_accuracy: 0.8591
# Epoch 27/50
# 36631/36631 [==============================] - 3s 79us/step - loss: 0.3048 - accuracy: 0.8596 - val_loss: 0.3065 - val_accuracy: 0.8593
# Epoch 28/50
# 36631/36631 [==============================] - 3s 77us/step - loss: 0.3035 - accuracy: 0.8579 - val_loss: 0.3071 - val_accuracy: 0.8586
# Epoch 29/50
# 36631/36631 [==============================] - 3s 79us/step - loss: 0.3026 - accuracy: 0.8583 - val_loss: 0.3064 - val_accuracy: 0.8599
# Epoch 30/50
# 36631/36631 [==============================] - 3s 79us/step - loss: 0.3026 - accuracy: 0.8562 - val_loss: 0.3073 - val_accuracy: 0.8558
# Epoch 31/50
# 36631/36631 [==============================] - 3s 80us/step - loss: 0.3008 - accuracy: 0.8607 - val_loss: 0.3073 - val_accuracy: 0.8578
# Epoch 32/50
# 36631/36631 [==============================] - 3s 82us/step - loss: 0.3010 - accuracy: 0.8610 - val_loss: 0.3080 - val_accuracy: 0.8603
# Epoch 33/50
# 36631/36631 [==============================] - 3s 77us/step - loss: 0.3004 - accuracy: 0.8611 - val_loss: 0.3071 - val_accuracy: 0.8590
# Epoch 34/50
# 36631/36631 [==============================] - 3s 77us/step - loss: 0.3006 - accuracy: 0.8591 - val_loss: 0.3070 - val_accuracy: 0.8577
# Epoch 35/50
# 36631/36631 [==============================] - 3s 82us/step - loss: 0.3009 - accuracy: 0.8600 - val_loss: 0.3069 - val_accuracy: 0.8608

# %%
_, val_acc_1 = model1.evaluate(test_X, test_Y)
_, val_acc_2 = model2.evaluate(test_X, test_Y)
_, val_acc_3 = model3.evaluate(test_X, test_Y)
_, val_acc_4 = model4.evaluate(test_X, test_Y)
print(f'Test set accuracy: \n Model_1: {val_acc_1} \n Model_2: {val_acc_2} \n Model_3: {val_acc_3} \n Model_4: {val_acc_4}')
# Out:
# 12211/12211 [==============================] - 0s 20us/step
# 12211/12211 [==============================] - 0s 20us/step
# 12211/12211 [==============================] - 0s 21us/step
# 12211/12211 [==============================] - 0s 23us/step
# Test set accuracy:
#  Model_1: 0.8603717684745789
#  Model_2: 0.8607812523841858
#  Model_3: 0.8606993556022644
#  Model_4: 0.8588158488273621
