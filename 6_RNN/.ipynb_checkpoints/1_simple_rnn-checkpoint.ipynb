# %% [markdown]
# # Recurrent Neural Networks
# RRNs are often used when dealing with sequences of variable lenght, like time-series. The goal, generally, is to predict the future behaviour of the series.

# %%
import numpy as np
import tensorflow as tf
import matplotlib as mpl
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from tensorflow.keras.losses import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, SimpleRNN, TimeDistributed

# %%
rndm_seed = 542
np.random.seed(rndm_seed)
tf.random.set_seed(rndm_seed)

# %% [markdown]
# ## What does it mean for a network to be recurrent?
# While in a traditional feedforward neural network the signal only flows in one direction, from the input to the output, recurrent networks have loops where the signal is going backward. At each step in time (t) a recurrent neuron will receive not only its current inputs ($x_t$), but also its own output at the previous timestep ($y_{t-1}$). Thus, each recurrent neurons will have (at least) two sets of weights, one for the current input ($w_x$) and one for the previous output ($w_y$). Since recurrent neurons and layers hold past information, or at least some of it, they are often referred to as memory cells.
# RNNs are classified according to their types of inputs and outputs:
# * Sequence-to-sequence networks take a sequence of inputs (e.g. stock prices over last N days) and return the same sequence shifted in the future (e.g. stock prices from N-1 days to tomorrow).
# * Sequence-to-vector networks take a sequence of inputs and return only the last output (e.g. stock price tomorrow, sentiment score, ...).
# * Vector-to-sequence networks take a single input (e.g. an image) and return a sequence (e.g. a caption for that image)
# * Encoder-Decoder networks are composed of a sequence-to-vector encoder followed by a vector-to-sequence decoder. This works better than a simple sequence-to-sequence network in certain scenarios.

# %% [markdown]
# ## Data
# Recurrent networks take a sequence of one or more values per timestep as their input. This sequences are most often time series, which can either be univariate or multivariate. The most common task is forecasting, however, also imputation of missing past values is possible.
#
# Let's generate synthetic time-series:

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offset1, offset2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time-offset1) * (freq1 * 10 + 10))
    series += 0.2 * np.sin((time-offset2) * (freq2 * 20 + 20))
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5)
    return series[..., np.newaxis].astype(np.float32)

# %% [markdown]
# And define a nice function for drawing time-series plots:

# %%
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$"):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bx", markersize=10)
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "ro")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])

# %% [markdown]
# Generate 3 synthetic time series, each 100 timesteps long.

# %%
x = generate_time_series(3, 100)

plt.figure(figsize=(10,10))
for i in range(3):
    plt.subplot(3,3,i+1)
    plt.plot(range(100), x[i,:,0])
plt.show()

# %% [markdown]
# Create a training, validation and test set.

# %%
n_steps = 50
series = generate_time_series(10000, n_steps+1)
x_train, y_train = series[:7000, :n_steps], series[:7000, -1]
x_val, y_val = series[7000:9000, :n_steps], series[7000:9000, -1]
x_test, y_test = series[9000:, :n_steps], series[9000:, -1]

print(f'Train X shape: {x_train.shape}')
print(f'Train Y shape: {y_train.shape}')
# Out:
# Train X shape: (7000, 50, 1)
# Train Y shape: (7000, 1)

# %% [markdown]
# And make a nice plot using the custom function:

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12, 4))
for col in range(3):
    plt.sca(axes[col])
    plot_series(x_val[col, :, 0], y_val[col, 0],
                y_label=("$x(t)$" if col==0 else None))
plt.show()

# %% [markdown]
# ## Baselines
# It is always nice to have to have some simple baselines against which to compare results from more complex models. The easiest possibility is to predict that the future value will be equal to last observed values in the series.  Alternatively, we could use a simple linear regression.

# %%
# 1) always predict last observed value
y_pred = x_val[:,-1]
mse = np.mean(mean_squared_error(y_val, y_pred))
print(f'Naive prediction MSE: {mse}')

# make a plot
plot_series(x_val[0, :, 0], y_val[0, 0], y_pred[0, 0])
plt.show()
# Out:
# Naive prediction MSE: 0.020818335935473442

# %%
np.random.seed(rndm_seed)
tf.random.set_seed(rndm_seed)

# 2) linear regression
model = Sequential([
        Flatten(input_shape = [n_steps, 1]),
        Dense(1)])
model.compile(loss = mean_squared_error, optimizer = 'nadam')
print('\n \n *** Training linear model: *** \n')
history = model.fit(x_train, y_train, epochs = 20, 
          validation_data = (x_val, y_val))

y_pred = model.predict(x_val)
mse = np.mean(mean_squared_error(y_val, y_pred))
print(f'\n Linear model MSE: {mse}')
# Out:
#
#  *** Training linear model: ***
#
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 1s 100us/sample - loss: 0.1086 - val_loss: 0.0300
# Epoch 2/20
# 7000/7000 [==============================] - 0s 52us/sample - loss: 0.0218 - val_loss: 0.0161
# Epoch 3/20
# 7000/7000 [==============================] - 0s 50us/sample - loss: 0.0145 - val_loss: 0.0125
# Epoch 4/20
# 7000/7000 [==============================] - 0s 51us/sample - loss: 0.0118 - val_loss: 0.0106
# Epoch 5/20
# 7000/7000 [==============================] - 0s 52us/sample - loss: 0.0102 - val_loss: 0.0093
# Epoch 6/20
# 7000/7000 [==============================] - 0s 50us/sample - loss: 0.0090 - val_loss: 0.0082
# Epoch 7/20
# 7000/7000 [==============================] - 0s 54us/sample - loss: 0.0080 - val_loss: 0.0073
# Epoch 8/20
# 7000/7000 [==============================] - 0s 49us/sample - loss: 0.0072 - val_loss: 0.0065
# Epoch 9/20
# 7000/7000 [==============================] - 0s 51us/sample - loss: 0.0065 - val_loss: 0.0059
# Epoch 10/20
# 7000/7000 [==============================] - 0s 51us/sample - loss: 0.0059 - val_loss: 0.0054
# Epoch 11/20
# 7000/7000 [==============================] - 0s 52us/sample - loss: 0.0055 - val_loss: 0.0049
# Epoch 12/20
# 7000/7000 [==============================] - 0s 50us/sample - loss: 0.0051 - val_loss: 0.0046
# Epoch 13/20
# 7000/7000 [==============================] - 0s 52us/sample - loss: 0.0048 - val_loss: 0.0044
# Epoch 14/20
# 7000/7000 [==============================] - 0s 55us/sample - loss: 0.0046 - val_loss: 0.0042
# Epoch 15/20
# 7000/7000 [==============================] - 0s 52us/sample - loss: 0.0044 - val_loss: 0.0040
# Epoch 16/20
# 7000/7000 [==============================] - 0s 52us/sample - loss: 0.0043 - val_loss: 0.0039
# Epoch 17/20
# 7000/7000 [==============================] - 0s 51us/sample - loss: 0.0041 - val_loss: 0.0040
# Epoch 18/20
# 7000/7000 [==============================] - 0s 52us/sample - loss: 0.0041 - val_loss: 0.0037
# Epoch 19/20
# 7000/7000 [==============================] - 0s 49us/sample - loss: 0.0040 - val_loss: 0.0037
# Epoch 20/20
# 7000/7000 [==============================] - 0s 51us/sample - loss: 0.0039 - val_loss: 0.0036
#
#  Linear model MSE: 0.0035725124180316925

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

    
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

plt.sca(axes[0])
plot_series(x_val[0, :, 0], y_val[0, 0], y_pred[0, 0])

plt.sca(axes[1])
plot_learning_curves(history.history["loss"], history.history["val_loss"])

plt.show()

# %% [markdown]
# ## Simple RNN (seq-to-vect)
# Let's begin with a very simple recurrent network that only has one hidden layer with one recurrent neuron. Notice that there is no need to fix the lenght of the series as we did with linear regression, instead, we can simply pass 'None' as the first dimension. Performances are worse than linear regression, most likely because the number of parameters is much lower!

# %%
np.random.seed(rndm_seed)
tf.random.set_seed(rndm_seed)

# Simple RNN (1 layer, 1 unit)
model = Sequential([
        SimpleRNN(1, input_shape = [None, 1])])
model.compile(loss = mean_squared_error, optimizer = 'nadam')

print('\n \n *** Training simpleRNN model: *** \n')
history = model.fit(x_train, y_train, epochs = 20, validation_data = (x_val, y_val))

y_pred = model.predict(x_val)
mse = np.mean(mean_squared_error(y_val, y_pred))
print(f'\n Simple RNN MSE: {mse}')
# Out:
#
#  *** Training simpleRNN model: ***
#
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 4s 518us/sample - loss: 0.1974 - val_loss: 0.1778
# Epoch 2/20
# 7000/7000 [==============================] - 2s 292us/sample - loss: 0.1636 - val_loss: 0.1489
# Epoch 3/20
# 7000/7000 [==============================] - 2s 321us/sample - loss: 0.1373 - val_loss: 0.1254
# Epoch 4/20
# 7000/7000 [==============================] - 2s 335us/sample - loss: 0.1139 - val_loss: 0.1020
# Epoch 5/20
# 7000/7000 [==============================] - 2s 281us/sample - loss: 0.0915 - val_loss: 0.0812
# Epoch 6/20
# 7000/7000 [==============================] - 2s 320us/sample - loss: 0.0721 - val_loss: 0.0631
# Epoch 7/20
# 7000/7000 [==============================] - 2s 335us/sample - loss: 0.0553 - val_loss: 0.0476
# Epoch 8/20
# 7000/7000 [==============================] - 2s 288us/sample - loss: 0.0413 - val_loss: 0.0349
# Epoch 9/20
# 7000/7000 [==============================] - 2s 302us/sample - loss: 0.0303 - val_loss: 0.0253
# Epoch 10/20
# 7000/7000 [==============================] - 2s 305us/sample - loss: 0.0223 - val_loss: 0.0189
# Epoch 11/20
# 7000/7000 [==============================] - 2s 288us/sample - loss: 0.0173 - val_loss: 0.0152
# Epoch 12/20
# 7000/7000 [==============================] - 2s 277us/sample - loss: 0.0146 - val_loss: 0.0134
# Epoch 13/20
# 7000/7000 [==============================] - 2s 278us/sample - loss: 0.0134 - val_loss: 0.0126
# Epoch 14/20
# 7000/7000 [==============================] - 2s 277us/sample - loss: 0.0129 - val_loss: 0.0123
# Epoch 15/20
# 7000/7000 [==============================] - 2s 287us/sample - loss: 0.0126 - val_loss: 0.0121
# Epoch 16/20
# 7000/7000 [==============================] - 2s 276us/sample - loss: 0.0124 - val_loss: 0.0119
# Epoch 17/20
# 7000/7000 [==============================] - 2s 275us/sample - loss: 0.0123 - val_loss: 0.0118
# Epoch 18/20
# 7000/7000 [==============================] - 2s 276us/sample - loss: 0.0122 - val_loss: 0.0117
# Epoch 19/20
# 7000/7000 [==============================] - 2s 288us/sample - loss: 0.0121 - val_loss: 0.0115
# Epoch 20/20
# 7000/7000 [==============================] - 2s 306us/sample - loss: 0.0120 - val_loss: 0.0114
#
#  Simple RNN MSE: 0.011438688263297081

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

plt.sca(axes[0])
plot_series(x_val[0, :, 0], y_val[0, 0], y_pred[0, 0])

plt.sca(axes[1])
plot_learning_curves(history.history["loss"], history.history["val_loss"])

plt.show()

# %% [markdown]
# **Stacking multiple recurrent layers** is simple and can improve performances in a important way. Notice that the argument 'return_sequences' should be set to true for all recurrent layers that are followed by another recurrent layer. Furthermore, as with CNNs, the last layer is usually dense.

# %%
np.random.seed(rndm_seed)
tf.random.set_seed(rndm_seed)

model = Sequential([
        SimpleRNN(20, return_sequences = True, input_shape = [None, 1]),
        SimpleRNN(20),
        Dense(1)])
model.compile(loss = mean_squared_error, optimizer = 'nadam')

print('\n \n *** Training DeepRNN model: *** \n')
model.fit(x_train, y_train, epochs = 20, 
          validation_data = (x_val, y_val))

y_pred = model.predict(x_val)
mse = np.mean(mean_squared_error(y_val, y_pred))
print(f'Deep RNN MSE: {mse}')
# Out:
#
#  *** Training DeepRNN model: ***
#
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 7s 949us/sample - loss: 0.0222 - val_loss: 0.0061
# Epoch 2/20
# 7000/7000 [==============================] - 5s 714us/sample - loss: 0.0049 - val_loss: 0.0040
# Epoch 3/20
# 7000/7000 [==============================] - 5s 715us/sample - loss: 0.0035 - val_loss: 0.0033
# Epoch 4/20
# 7000/7000 [==============================] - 5s 711us/sample - loss: 0.0031 - val_loss: 0.0028
# Epoch 5/20
# 7000/7000 [==============================] - 5s 653us/sample - loss: 0.0030 - val_loss: 0.0027
# Epoch 6/20
# 7000/7000 [==============================] - 5s 653us/sample - loss: 0.0029 - val_loss: 0.0032
# Epoch 7/20
# 7000/7000 [==============================] - 5s 648us/sample - loss: 0.0029 - val_loss: 0.0026
# Epoch 8/20
# 7000/7000 [==============================] - 5s 688us/sample - loss: 0.0029 - val_loss: 0.0026
# Epoch 9/20
# 7000/7000 [==============================] - 5s 712us/sample - loss: 0.0028 - val_loss: 0.0027
# Epoch 10/20
# 7000/7000 [==============================] - 5s 667us/sample - loss: 0.0028 - val_loss: 0.0026
# Epoch 11/20
# 7000/7000 [==============================] - 5s 714us/sample - loss: 0.0027 - val_loss: 0.0026
# Epoch 12/20
# 7000/7000 [==============================] - 5s 698us/sample - loss: 0.0027 - val_loss: 0.0025
# Epoch 13/20
# 7000/7000 [==============================] - 5s 699us/sample - loss: 0.0027 - val_loss: 0.0026
# Epoch 14/20
# 7000/7000 [==============================] - 5s 690us/sample - loss: 0.0026 - val_loss: 0.0025
# Epoch 15/20
# 7000/7000 [==============================] - 5s 716us/sample - loss: 0.0026 - val_loss: 0.0026
# Epoch 16/20
# 7000/7000 [==============================] - 5s 667us/sample - loss: 0.0026 - val_loss: 0.0025
# Epoch 17/20
# 7000/7000 [==============================] - 5s 653us/sample - loss: 0.0026 - val_loss: 0.0027
# Epoch 18/20
# 7000/7000 [==============================] - 5s 651us/sample - loss: 0.0025 - val_loss: 0.0026
# Epoch 19/20
# 7000/7000 [==============================] - 5s 662us/sample - loss: 0.0025 - val_loss: 0.0026
# Epoch 20/20
# 7000/7000 [==============================] - 5s 651us/sample - loss: 0.0025 - val_loss: 0.0025
# Deep RNN MSE: 0.002487893681973219

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

plt.sca(axes[0])
plot_series(x_val[0, :, 0], y_val[0, 0], y_pred[0, 0])

plt.sca(axes[1])
plot_learning_curves(history.history["loss"], history.history["val_loss"])

plt.show()

# %% [markdown]
# ### Making predictions deeper in time
# Rather than predicting only the value of $y$ tomorrow, we may want to make a prediction several steps ahead (e.g. next 10 values).  One naive possibility is to train the network, make a prediction, add it to the inputs, make a new prediction and so.

# %%
np.random.seed(rndm_seed+342)

series2 = generate_time_series(1, n_steps + 10)
x_new, y_new = series2[:, :n_steps], series2[:, n_steps:]

x = x_new
for step in range(10):
    y_pred_one = model.predict(x[:, step:])[:, np.newaxis, :]
    x = np.concatenate([x, y_pred_one], axis=1)
    
y_pred = x[:, n_steps:]
print(f'Predictions shape: {y_pred.shape}')

mse = np.mean(mean_squared_error(y_new, y_pred))
print(f'Predictions MSE: {mse}')
# Out:
# Predictions shape: (1, 10, 1)
# Predictions MSE: 0.007828021422028542

# %%
def plot_multiple_forecasts(X, Y, Y_pred):
    n_steps = X.shape[1]
    ahead = Y.shape[1]
    plot_series(X[0, :, 0])
    plt.plot(np.arange(n_steps, n_steps + ahead), Y[0, :, 0], "ro-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), Y_pred[0, :, 0], "bx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)

plot_multiple_forecasts(x_new, y_new, y_pred)
plt.show()

# %% [markdown]
# Another possibility is to directly train the network to predict several timesteps ahead. In order to do this, we have to redefine the training, validation and test sets.

# %%
np.random.seed(rndm_seed)
n_steps = 50

series = generate_time_series(10000, n_steps+10)
x_train, y_train = series[:7000, :n_steps], series[:7000, -10:, 0]
x_val, y_val = series[7000:9000, :n_steps], series[7000:9000, -10:, 0]
x_test, y_test = series[9000:, :n_steps], series[9000:, -10:, 0]

# %% [markdown]
# Try again to make predictions one by one.

# %%
x = x_val
for step_ahead in range(10):
    y_pred_one = model.predict(x)[:, np.newaxis, :]
    x = np.concatenate([x, y_pred_one], axis=1)

y_pred = x[:, n_steps:, 0]
print(f'Predictions shape: {y_pred.shape}')

mse = np.mean(mean_squared_error(y_val, y_pred))
print(f'Predictions MSE: {mse}')
# Out:
# Predictions shape: (2000, 10)
# Predictions MSE: 0.028742225840687752

# %% [markdown]
# Naive-prediction (equal to last observed value):

# %%
Y_naive_pred = y_val[:, -1:]
mse = np.mean(mean_squared_error(y_val, Y_naive_pred))
print(f'Predictions MSE: {mse}')
# Out:
# Predictions MSE: 0.21207420527935028

# %% [markdown]
# Finally, let's make a RNN that predicts all the 10 future values at once:

# %%
np.random.seed(rndm_seed)
tf.random.set_seed(rndm_seed)

model = Sequential([
        SimpleRNN(20, return_sequences = True, input_shape = [None, 1]),
        SimpleRNN(20),
        Dense(10)])
model.compile(loss = 'mse', optimizer = 'nadam')

print('\n \n *** Training 10 steps-ahead DeepRNN model: *** \n')
history = model.fit(x_train, y_train, epochs = 20, 
          validation_data = (x_val, y_val))
# Out:
#
#  *** Training 10 steps-ahead DeepRNN model: ***
#
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 7s 937us/sample - loss: 0.0622 - val_loss: 0.0328
# Epoch 2/20
# 7000/7000 [==============================] - 5s 671us/sample - loss: 0.0248 - val_loss: 0.0256
# Epoch 3/20
# 7000/7000 [==============================] - 5s 757us/sample - loss: 0.0176 - val_loss: 0.0151
# Epoch 4/20
# 7000/7000 [==============================] - 5s 769us/sample - loss: 0.0146 - val_loss: 0.0137
# Epoch 5/20
# 7000/7000 [==============================] - 5s 722us/sample - loss: 0.0131 - val_loss: 0.0124
# Epoch 6/20
# 7000/7000 [==============================] - 5s 709us/sample - loss: 0.0119 - val_loss: 0.0127
# Epoch 7/20
# 7000/7000 [==============================] - 5s 695us/sample - loss: 0.0114 - val_loss: 0.0108
# Epoch 8/20
# 7000/7000 [==============================] - 5s 722us/sample - loss: 0.0107 - val_loss: 0.0105
# Epoch 9/20
# 7000/7000 [==============================] - 5s 688us/sample - loss: 0.0102 - val_loss: 0.0105
# Epoch 10/20
# 7000/7000 [==============================] - 5s 718us/sample - loss: 0.0100 - val_loss: 0.0095
# Epoch 11/20
# 7000/7000 [==============================] - 5s 691us/sample - loss: 0.0097 - val_loss: 0.0096
# Epoch 12/20
# 7000/7000 [==============================] - 5s 695us/sample - loss: 0.0095 - val_loss: 0.0100
# Epoch 13/20
# 7000/7000 [==============================] - 5s 743us/sample - loss: 0.0094 - val_loss: 0.0093
# Epoch 14/20
# 7000/7000 [==============================] - 6s 801us/sample - loss: 0.0092 - val_loss: 0.0105
# Epoch 15/20
# 7000/7000 [==============================] - 5s 704us/sample - loss: 0.0090 - val_loss: 0.0102
# Epoch 16/20
# 7000/7000 [==============================] - 5s 718us/sample - loss: 0.0090 - val_loss: 0.0098
# Epoch 17/20
# 7000/7000 [==============================] - 5s 692us/sample - loss: 0.0087 - val_loss: 0.0092
# Epoch 18/20
# 7000/7000 [==============================] - 5s 686us/sample - loss: 0.0086 - val_loss: 0.0105
# Epoch 19/20
# 7000/7000 [==============================] - 5s 725us/sample - loss: 0.0086 - val_loss: 0.0087
# Epoch 20/20
# 7000/7000 [==============================] - 5s 732us/sample - loss: 0.0086 - val_loss: 0.0091

# %%
np.random.seed(rndm_seed+342)

series2 = generate_time_series(1, n_steps + 10)
x_new, y_new = series2[:, :n_steps, :], series2[:, n_steps:, :]

y_pred = model.predict(x_new)[..., np.newaxis]
print(f'Predictions shape: {y_pred.shape}')

mse = np.mean(mean_squared_error(y_new, y_pred))
print(f'Predictions MSE: {mse}')
# Out:
# Predictions shape: (1, 10, 1)
# Predictions MSE: 0.004085707012563944

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

plt.sca(axes[0])
plot_multiple_forecasts(x_new, y_new, y_pred)

plt.sca(axes[1])
plot_learning_curves(history.history["loss"], history.history["val_loss"])

plt.show()

# %% [markdown]
# ## Simple RNN (seq-to-seq)
# A sequence to sequence network will output a vector of forecasts at each timestep (e.g. at step 0, forecast from 1 to 10, at step 1 forecast from 2 to 11, and so on). Each target must be a sequence of same lenght as the input sequence.

# %%
y = np.empty((10000, n_steps, 10))
for step in range(1, 10+1):
    y[:, :, step-1] = series[:, step:step + n_steps, 0]
    
y_train = y[:7000]
y_val = y[7000:9000]
y_test = y[9000:]

# print some shapes
print(f'x_train shape: {x_train.shape}')
print(f'y_train shape: {y_train.shape}')
# Out:
# x_train shape: (7000, 50, 1)
# y_train shape: (7000, 50, 10)

# %% [markdown]
# Define and train the sequence-to-sequence network:

# %%
np.random.seed(rndm_seed)
tf.random.set_seed(rndm_seed)

model = Sequential([
        SimpleRNN(20, return_sequences = True, input_shape = [None, 1]),
        SimpleRNN(20, return_sequences = True),
        TimeDistributed(Dense(10))
])

def last_time_step_mse(y_true, y_pred):
    return mean_squared_error(y_true[:, -1], y_pred[:, -1])

model.compile(loss = 'mse', optimizer = 'nadam', metrics = [last_time_step_mse])

print('\n \n *** Training seq-to-seq DeepRNN model: *** \n')
history = model.fit(x_train, y_train, epochs = 20, 
          validation_data = (x_val, y_val))
# Out:
#
#  *** Training seq-to-seq DeepRNN model: ***
#
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 7s 994us/sample - loss: 0.0721 - last_time_step_mse: 0.0619 - val_loss: 0.0491 - val_last_time_step_mse: 0.0388
# Epoch 2/20
# 7000/7000 [==============================] - 6s 806us/sample - loss: 0.0441 - last_time_step_mse: 0.0319 - val_loss: 0.0409 - val_last_time_step_mse: 0.0278
# Epoch 3/20
# 7000/7000 [==============================] - 5s 710us/sample - loss: 0.0392 - last_time_step_mse: 0.0259 - val_loss: 0.0379 - val_last_time_step_mse: 0.0255
# Epoch 4/20
# 7000/7000 [==============================] - 6s 811us/sample - loss: 0.0364 - last_time_step_mse: 0.0227 - val_loss: 0.0365 - val_last_time_step_mse: 0.0236
# Epoch 5/20
# 7000/7000 [==============================] - 5s 705us/sample - loss: 0.0345 - last_time_step_mse: 0.0205 - val_loss: 0.0336 - val_last_time_step_mse: 0.0197
# Epoch 6/20
# 7000/7000 [==============================] - 5s 707us/sample - loss: 0.0331 - last_time_step_mse: 0.0190 - val_loss: 0.0340 - val_last_time_step_mse: 0.0204
# Epoch 7/20
# 7000/7000 [==============================] - 5s 655us/sample - loss: 0.0320 - last_time_step_mse: 0.0174 - val_loss: 0.0313 - val_last_time_step_mse: 0.0167
# Epoch 8/20
# 7000/7000 [==============================] - 5s 686us/sample - loss: 0.0312 - last_time_step_mse: 0.0165 - val_loss: 0.0313 - val_last_time_step_mse: 0.0162
# Epoch 9/20
# 7000/7000 [==============================] - 5s 705us/sample - loss: 0.0303 - last_time_step_mse: 0.0155 - val_loss: 0.0298 - val_last_time_step_mse: 0.0151
# Epoch 10/20
# 7000/7000 [==============================] - 5s 694us/sample - loss: 0.0298 - last_time_step_mse: 0.0149 - val_loss: 0.0296 - val_last_time_step_mse: 0.0147
# Epoch 11/20
# 7000/7000 [==============================] - 5s 699us/sample - loss: 0.0293 - last_time_step_mse: 0.0144 - val_loss: 0.0289 - val_last_time_step_mse: 0.0138
# Epoch 12/20
# 7000/7000 [==============================] - 5s 701us/sample - loss: 0.0288 - last_time_step_mse: 0.0138 - val_loss: 0.0285 - val_last_time_step_mse: 0.0134
# Epoch 13/20
# 7000/7000 [==============================] - 5s 711us/sample - loss: 0.0283 - last_time_step_mse: 0.0133 - val_loss: 0.0301 - val_last_time_step_mse: 0.0161
# Epoch 14/20
# 7000/7000 [==============================] - 5s 715us/sample - loss: 0.0278 - last_time_step_mse: 0.0129 - val_loss: 0.0286 - val_last_time_step_mse: 0.0141
# Epoch 15/20
# 7000/7000 [==============================] - 5s 726us/sample - loss: 0.0276 - last_time_step_mse: 0.0128 - val_loss: 0.0272 - val_last_time_step_mse: 0.0120
# Epoch 16/20
# 7000/7000 [==============================] - 5s 760us/sample - loss: 0.0271 - last_time_step_mse: 0.0123 - val_loss: 0.0283 - val_last_time_step_mse: 0.0138
# Epoch 17/20
# 7000/7000 [==============================] - 5s 767us/sample - loss: 0.0269 - last_time_step_mse: 0.0121 - val_loss: 0.0268 - val_last_time_step_mse: 0.0119
# Epoch 18/20
# 7000/7000 [==============================] - 5s 718us/sample - loss: 0.0265 - last_time_step_mse: 0.0118 - val_loss: 0.0273 - val_last_time_step_mse: 0.0129
# Epoch 19/20
# 7000/7000 [==============================] - 5s 708us/sample - loss: 0.0262 - last_time_step_mse: 0.0115 - val_loss: 0.0260 - val_last_time_step_mse: 0.0113
# Epoch 20/20
# 7000/7000 [==============================] - 5s 709us/sample - loss: 0.0259 - last_time_step_mse: 0.0114 - val_loss: 0.0267 - val_last_time_step_mse: 0.0124

# %%
np.random.seed(rndm_seed+342)

series2 = generate_time_series(1, n_steps + 10)
x_new, y_new = series2[:, :n_steps, :], series2[:, n_steps:, :]

y_pred = model.predict(x_new)[:, -1][..., np.newaxis]
print(f'x_new shape: {x_new.shape}')
print(f'y_new shape: {y_new.shape}')
print(f'Predictions shape: {y_pred.shape}')

ls_mse = np.mean(last_time_step_mse(y_new, y_pred))
mse = np.mean(mean_squared_error(y_new, y_pred))
print(f'Predictions last-TS MSE: {ls_mse}')
print(f'Predictions MSE: {mse}')
# Out:
# x_new shape: (1, 50, 1)
# y_new shape: (1, 10, 1)
# Predictions shape: (1, 10, 1)
# Predictions last-TS MSE: 0.0036535647232085466
# Predictions MSE: 0.0026886751875281334

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

plt.sca(axes[0])
plot_multiple_forecasts(x_new, y_new, y_pred)

plt.sca(axes[1])
plot_learning_curves(history.history["loss"], history.history["val_loss"])

plt.show()
